# %%
G=Graph({0:[1,2,3], 4:[0,2], 6:[1,2,3,4,5]})
#G.add_edges( [(0,1,'a'),(1,2,'b'),(2,3,'c'),(3,4,'b'),(4,0,'a')] )
G.plot(color_by_label={'a':'purple', 'b':'blue', 'c':'green'})
G.plot(color_by_label=True)
show(G)
for e in G.edges():
    print e
# Out:
# Graphics object consisting of 18 graphics primitives
# (0, 1, None)
# (0, 2, None)
# (0, 3, None)
# (0, 4, None)
# (1, 6, None)
# (2, 4, None)
# (2, 6, None)
# (3, 6, None)
# (4, 6, None)
# (5, 6, None)

# %%
H.set_pos(H.layout_circular())
plot(H)
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
G = Graph()
G.add_vertices(range(10)); G
show(G)
G.add_path(list(range(10,20)))
show(G)
G.add_path(list(range(10)))
show(G)
# Out:
# Graphics object consisting of 11 graphics primitives
# Graphics object consisting of 30 graphics primitives
# Graphics object consisting of 39 graphics primitives
